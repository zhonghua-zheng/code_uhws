# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the UHWs using **CESM-LE**
#
# The data sets are from:
# ```bash
# /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-urban-temp-extracted-csv/
# ```
#
# The results are saved at:
# ```
# S3://uhws/UHWs_CESM/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import time
import gc
import util
from s3fs.core import S3FileSystem
s3 = S3FileSystem()

save_dir = "S3://uhws/UHWs_CESM/"

# %% [markdown]
# ## Step 1: Load 2006 and 2061 data

# %%
cesm_2006 = util.load_df("/data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-urban-temp-extracted-csv"\
                         "/urban_heat_LE_2006.csv")
cesm_2061 = util.load_df("/data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-urban-temp-extracted-csv"\
                         "/urban_heat_LE_2061.csv")
# Out:
# Start to load csv /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-urban-temp-extracted-csv/urban_heat_LE_2006.csv
# It takes 99.07164168357849 to load csv
# Start to load csv /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-urban-temp-extracted-csv/urban_heat_LE_2061.csv
# It takes 184.09930396080017 to load csv

# %% [markdown]
# ## Step 2: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
# create member_ls
member_ls = []
for i in range(2,34):
    member_idx = (str(i).zfill(3))
    member_ls.append(member_idx+"_max")

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]
quantile_avail_2061_ls=[]
for member in member_ls:
    print("start member:",member)
    
    # start 2006
    start_time_2006=time.time()
    cesm_2006_hw, quantile_avail_2006=util.get_heat_waves_df(cesm_2006[["lat","lon","time",member]], 0.98, 2, "cesm", None)
    
    frequency_2006_ls.append(util.get_frequency(cesm_2006_hw,member))
    duration_2006_ls.append(util.get_duration(cesm_2006_hw,member))
    intensity_2006_ls.append(util.get_intensity(cesm_2006_hw,member))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",member,"for year 2006")
    
    # start 2061
    start_time_2061=time.time()
    cesm_2061_hw, quantile_avail_2061=util.get_heat_waves_df(cesm_2061[["lat","lon","time",member]], None, 2, "cesm", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cesm_2061_hw,member))
    duration_2061_ls.append(util.get_duration(cesm_2061_hw,member))
    intensity_2061_ls.append(util.get_intensity(cesm_2061_hw,member))
    quantile_avail_2061_ls.append(quantile_avail_2061.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2061,"to deal with",member,"for year 2061")
    print("\n")
    
    del cesm_2006_hw, cesm_2061_hw, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start member: 002_max
# The quantile is: 0.98
# The duration threshold is: 2
# /data/keeling/a/zzheng25/UrbanHWs/event_analysis/v4/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 31.408921718597412 to deal with 002_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 23.147963523864746 to deal with 002_max for year 2061
#
#
# start member: 003_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.144307374954224 to deal with 003_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.88884925842285 to deal with 003_max for year 2061
#
#
# start member: 004_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.903324127197266 to deal with 004_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.92422604560852 to deal with 004_max for year 2061
#
#
# start member: 005_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.89483094215393 to deal with 005_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.984957218170166 to deal with 005_max for year 2061
#
#
# start member: 006_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.7478244304657 to deal with 006_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.92989444732666 to deal with 006_max for year 2061
#
#
# start member: 007_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.672192573547363 to deal with 007_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.973339557647705 to deal with 007_max for year 2061
#
#
# start member: 008_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.46178436279297 to deal with 008_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.71743106842041 to deal with 008_max for year 2061
#
#
# start member: 009_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.162144422531128 to deal with 009_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.036830186843872 to deal with 009_max for year 2061
#
#
# start member: 010_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.4509596824646 to deal with 010_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.676508903503418 to deal with 010_max for year 2061
#
#
# start member: 011_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.894041299819946 to deal with 011_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.128106117248535 to deal with 011_max for year 2061
#
#
# start member: 012_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.978962182998657 to deal with 012_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.791704177856445 to deal with 012_max for year 2061
#
#
# start member: 013_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.912192821502686 to deal with 013_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.0140221118927 to deal with 013_max for year 2061
#
#
# start member: 014_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.90418529510498 to deal with 014_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.00374722480774 to deal with 014_max for year 2061
#
#
# start member: 015_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.813758611679077 to deal with 015_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.855382442474365 to deal with 015_max for year 2061
#
#
# start member: 016_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.863742113113403 to deal with 016_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.023184537887573 to deal with 016_max for year 2061
#
#
# start member: 017_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.921228885650635 to deal with 017_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.022842407226562 to deal with 017_max for year 2061
#
#
# start member: 018_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.92223525047302 to deal with 018_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.525997161865234 to deal with 018_max for year 2061
#
#
# start member: 019_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.05681276321411 to deal with 019_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.34029531478882 to deal with 019_max for year 2061
#
#
# start member: 020_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.646438360214233 to deal with 020_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.90919303894043 to deal with 020_max for year 2061
#
#
# start member: 021_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.41295623779297 to deal with 021_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.46345067024231 to deal with 021_max for year 2061
#
#
# start member: 022_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.9760684967041 to deal with 022_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.485992193222046 to deal with 022_max for year 2061
#
#
# start member: 023_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.775204181671143 to deal with 023_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.988532781600952 to deal with 023_max for year 2061
#
#
# start member: 024_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.464036226272583 to deal with 024_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.24557328224182 to deal with 024_max for year 2061
#
#
# start member: 025_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.90360140800476 to deal with 025_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.744709253311157 to deal with 025_max for year 2061
#
#
# start member: 026_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.997762203216553 to deal with 026_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.147704124450684 to deal with 026_max for year 2061
#
#
# start member: 027_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.46183466911316 to deal with 027_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.16035532951355 to deal with 027_max for year 2061
#
#
# start member: 028_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 31.484139442443848 to deal with 028_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.00414514541626 to deal with 028_max for year 2061
#
#
# start member: 029_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.54878568649292 to deal with 029_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.106130599975586 to deal with 029_max for year 2061
#
#
# start member: 030_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.519434213638306 to deal with 030_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.470420360565186 to deal with 030_max for year 2061
#
#
# start member: 031_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.40331244468689 to deal with 031_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.672589778900146 to deal with 031_max for year 2061
#
#
# start member: 032_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.170659065246582 to deal with 032_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.18928861618042 to deal with 032_max for year 2061
#
#
# start member: 033_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.483010292053223 to deal with 033_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.137532949447632 to deal with 033_max for year 2061

# %% [markdown]
# ## Merge to dataframe and save as csv

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)
quantile_avail_2061 = pd.concat(quantile_avail_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
quantile_avail_2061.to_csv(save_dir+"2061_percentile.csv")
