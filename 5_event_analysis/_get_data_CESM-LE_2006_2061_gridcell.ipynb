# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the HWs using **CESM-LE**
#
# The data sets are from:
# ```bash
# /glade/scratch/zhonghua/CESM-LE-members-gridcell-temp-extracted-csv/
# ```
#
# The results are saved at:
# ```
# /glade/scratch/zhonghua/uhws/HWs_CESM/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import time
import gc
import util
# from s3fs.core import S3FileSystem
# s3 = S3FileSystem()

save_dir = "/glade/scratch/zhonghua/uhws/HWs_CESM/"

# %% [markdown]
# ## Step 1: Load 2006 and 2061 data

# %%
cesm_2006 = util.load_df("/glade/scratch/zhonghua/CESM-LE-members-gridcell-temp-extracted-csv"\
                         "/TREFHTMX_heat_LE_2006.csv")
cesm_2061 = util.load_df("/glade/scratch/zhonghua/CESM-LE-members-gridcell-temp-extracted-csv"\
                         "/TREFHTMX_heat_LE_2061.csv")
# Out:
# Start to load csv /glade/scratch/zhonghua/CESM-LE-members-gridcell-temp-extracted-csv/TREFHTMX_heat_LE_2006.csv
# It takes 59.93881106376648 to load csv
# Start to load csv /glade/scratch/zhonghua/CESM-LE-members-gridcell-temp-extracted-csv/TREFHTMX_heat_LE_2061.csv
# It takes 59.19037079811096 to load csv

# %% [markdown]
# ## Step 2: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
# create member_ls
member_ls = []
for i in range(2,34):
    member_idx = (str(i).zfill(3))
    member_ls.append(member_idx+"_max")

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]
quantile_avail_2061_ls=[]
for member in member_ls:
    print("start member:",member)
    
    # start 2006
    start_time_2006=time.time()
    cesm_2006_hw, quantile_avail_2006=util.get_heat_waves_df(cesm_2006[["lat","lon","time",member]], 0.98, 2, "cesm", None)
    
    frequency_2006_ls.append(util.get_frequency(cesm_2006_hw,member))
    duration_2006_ls.append(util.get_duration(cesm_2006_hw,member))
    intensity_2006_ls.append(util.get_intensity(cesm_2006_hw,member))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",member,"for year 2006")
    
    # start 2061
    start_time_2061=time.time()
    cesm_2061_hw, quantile_avail_2061=util.get_heat_waves_df(cesm_2061[["lat","lon","time",member]], None, 2, "cesm", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cesm_2061_hw,member))
    duration_2061_ls.append(util.get_duration(cesm_2061_hw,member))
    intensity_2061_ls.append(util.get_intensity(cesm_2061_hw,member))
    quantile_avail_2061_ls.append(quantile_avail_2061.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2061,"to deal with",member,"for year 2061")
    print("\n")
    
    del cesm_2006_hw, cesm_2061_hw, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start member: 002_max
# The quantile is: 0.98
# The duration threshold is: 2
# /glade/work/zhonghua/code_uhws_ncc_private/3_revision/5_event_analysis/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 28.524385452270508 to deal with 002_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.11390709877014 to deal with 002_max for year 2061
#
#
# start member: 003_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.669853687286377 to deal with 003_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.799935340881348 to deal with 003_max for year 2061
#
#
# start member: 004_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.819986581802368 to deal with 004_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.786059856414795 to deal with 004_max for year 2061
#
#
# start member: 005_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 26.138872861862183 to deal with 005_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.775070428848267 to deal with 005_max for year 2061
#
#
# start member: 006_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.695154666900635 to deal with 006_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.27778124809265 to deal with 006_max for year 2061
#
#
# start member: 007_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.37471342086792 to deal with 007_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.014060020446777 to deal with 007_max for year 2061
#
#
# start member: 008_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.50984215736389 to deal with 008_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.82013463973999 to deal with 008_max for year 2061
#
#
# start member: 009_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.451438903808594 to deal with 009_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.918678522109985 to deal with 009_max for year 2061
#
#
# start member: 010_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.966728925704956 to deal with 010_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.195563554763794 to deal with 010_max for year 2061
#
#
# start member: 011_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.59070348739624 to deal with 011_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.817373514175415 to deal with 011_max for year 2061
#
#
# start member: 012_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.793447017669678 to deal with 012_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 23.6060848236084 to deal with 012_max for year 2061
#
#
# start member: 013_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.539687871932983 to deal with 013_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 21.651414394378662 to deal with 013_max for year 2061
#
#
# start member: 014_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.537719249725342 to deal with 014_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.932929277420044 to deal with 014_max for year 2061
#
#
# start member: 015_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.986414670944214 to deal with 015_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.89301371574402 to deal with 015_max for year 2061
#
#
# start member: 016_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.04297161102295 to deal with 016_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.39988136291504 to deal with 016_max for year 2061
#
#
# start member: 017_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.026126623153687 to deal with 017_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.222697496414185 to deal with 017_max for year 2061
#
#
# start member: 018_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.19680619239807 to deal with 018_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.222264051437378 to deal with 018_max for year 2061
#
#
# start member: 019_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.119622468948364 to deal with 019_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.132165670394897 to deal with 019_max for year 2061
#
#
# start member: 020_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.216583013534546 to deal with 020_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.193386793136597 to deal with 020_max for year 2061
#
#
# start member: 021_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.65477418899536 to deal with 021_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.8252010345459 to deal with 021_max for year 2061
#
#
# start member: 022_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.20814299583435 to deal with 022_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.6178195476532 to deal with 022_max for year 2061
#
#
# start member: 023_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.202977418899536 to deal with 023_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.4801664352417 to deal with 023_max for year 2061
#
#
# start member: 024_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.1573224067688 to deal with 024_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.561075448989868 to deal with 024_max for year 2061
#
#
# start member: 025_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.72561240196228 to deal with 025_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.798523902893066 to deal with 025_max for year 2061
#
#
# start member: 026_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.468777894973755 to deal with 026_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.98229718208313 to deal with 026_max for year 2061
#
#
# start member: 027_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.586923122406006 to deal with 027_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.68031668663025 to deal with 027_max for year 2061
#
#
# start member: 028_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 26.431795120239258 to deal with 028_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.845565795898438 to deal with 028_max for year 2061
#
#
# start member: 029_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.53188967704773 to deal with 029_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.84693670272827 to deal with 029_max for year 2061
#
#
# start member: 030_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 25.499082326889038 to deal with 030_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 20.977453231811523 to deal with 030_max for year 2061
#
#
# start member: 031_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 26.9939968585968 to deal with 031_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.583832025527954 to deal with 031_max for year 2061
#
#
# start member: 032_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 30.669413328170776 to deal with 032_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.54665970802307 to deal with 032_max for year 2061
#
#
# start member: 033_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 26.58734130859375 to deal with 033_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 24.56270456314087 to deal with 033_max for year 2061

# %% [markdown]
# ## Merge to dataframe and save as csv

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)
quantile_avail_2061 = pd.concat(quantile_avail_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
quantile_avail_2061.to_csv(save_dir+"2061_percentile.csv")
