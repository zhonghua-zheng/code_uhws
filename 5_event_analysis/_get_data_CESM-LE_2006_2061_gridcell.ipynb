# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the HWs using **CESM-LE**
#
# The data sets are from:
# ```bash
# /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-gridcell-temp-extracted-csv/
# ```
#
# The results are saved at:
# ```
# S3://uhws/HWs_CESM/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import time
import gc
import util
from s3fs.core import S3FileSystem
s3 = S3FileSystem()

save_dir = "S3://uhws/HWs_CESM/"

# %% [markdown]
# ## Step 1: Load 2006 and 2061 data

# %%
cesm_2006 = util.load_df("/data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-gridcell-temp-extracted-csv"\
                         "/TREFHTMX_heat_LE_2006.csv")
cesm_2061 = util.load_df("/data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-gridcell-temp-extracted-csv"\
                         "/TREFHTMX_heat_LE_2061.csv")
# Out:
# Start to load csv /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-gridcell-temp-extracted-csv/TREFHTMX_heat_LE_2006.csv
# It takes 191.3726840019226 to load csv
# Start to load csv /data/keeling/a/zzheng25/d/CESM-LE/CESM-LE-members-gridcell-temp-extracted-csv/TREFHTMX_heat_LE_2061.csv
# It takes 308.4626851081848 to load csv

# %% [markdown]
# ## Step 2: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
# create member_ls
member_ls = []
for i in range(2,34):
    member_idx = (str(i).zfill(3))
    member_ls.append(member_idx+"_max")

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]
quantile_avail_2061_ls=[]
for member in member_ls:
    print("start member:",member)
    
    # start 2006
    start_time_2006=time.time()
    cesm_2006_hw, quantile_avail_2006=util.get_heat_waves_df(cesm_2006[["lat","lon","time",member]], 0.98, 2, "cesm", None)
    
    frequency_2006_ls.append(util.get_frequency(cesm_2006_hw,member))
    duration_2006_ls.append(util.get_duration(cesm_2006_hw,member))
    intensity_2006_ls.append(util.get_intensity(cesm_2006_hw,member))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",member,"for year 2006")
    
    # start 2061
    start_time_2061=time.time()
    cesm_2061_hw, quantile_avail_2061=util.get_heat_waves_df(cesm_2061[["lat","lon","time",member]], None, 2, "cesm", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cesm_2061_hw,member))
    duration_2061_ls.append(util.get_duration(cesm_2061_hw,member))
    intensity_2061_ls.append(util.get_intensity(cesm_2061_hw,member))
    quantile_avail_2061_ls.append(quantile_avail_2061.copy().rename(columns={"quant": member}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2061,"to deal with",member,"for year 2061")
    print("\n")
    
    del cesm_2006_hw, cesm_2061_hw, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start member: 002_max
# The quantile is: 0.98
# The duration threshold is: 2
# /data/keeling/a/zzheng25/UrbanHWs/event_analysis/v4/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 31.995909690856934 to deal with 002_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.3153715133667 to deal with 002_max for year 2061
#
#
# start member: 003_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.694092750549316 to deal with 003_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.384760856628418 to deal with 003_max for year 2061
#
#
# start member: 004_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.556496620178223 to deal with 004_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.963393211364746 to deal with 004_max for year 2061
#
#
# start member: 005_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.678916931152344 to deal with 005_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.219956636428833 to deal with 005_max for year 2061
#
#
# start member: 006_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.31655311584473 to deal with 006_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.53048586845398 to deal with 006_max for year 2061
#
#
# start member: 007_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 33.03301191329956 to deal with 007_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.649172067642212 to deal with 007_max for year 2061
#
#
# start member: 008_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.712218761444092 to deal with 008_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.44996976852417 to deal with 008_max for year 2061
#
#
# start member: 009_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.403794527053833 to deal with 009_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.81450605392456 to deal with 009_max for year 2061
#
#
# start member: 010_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.28698754310608 to deal with 010_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.564054489135742 to deal with 010_max for year 2061
#
#
# start member: 011_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.513903617858887 to deal with 011_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.683188438415527 to deal with 011_max for year 2061
#
#
# start member: 012_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.396205186843872 to deal with 012_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.49219059944153 to deal with 012_max for year 2061
#
#
# start member: 013_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.533772230148315 to deal with 013_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.20848250389099 to deal with 013_max for year 2061
#
#
# start member: 014_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 26.98832654953003 to deal with 014_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.655237436294556 to deal with 014_max for year 2061
#
#
# start member: 015_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.54534411430359 to deal with 015_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.641202926635742 to deal with 015_max for year 2061
#
#
# start member: 016_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.21234154701233 to deal with 016_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.387544870376587 to deal with 016_max for year 2061
#
#
# start member: 017_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.635396242141724 to deal with 017_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.170624017715454 to deal with 017_max for year 2061
#
#
# start member: 018_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.39316725730896 to deal with 018_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.457475185394287 to deal with 018_max for year 2061
#
#
# start member: 019_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.716350078582764 to deal with 019_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.455037117004395 to deal with 019_max for year 2061
#
#
# start member: 020_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.44676423072815 to deal with 020_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.01933789253235 to deal with 020_max for year 2061
#
#
# start member: 021_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.85932230949402 to deal with 021_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.002270221710205 to deal with 021_max for year 2061
#
#
# start member: 022_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.691020488739014 to deal with 022_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.063315391540527 to deal with 022_max for year 2061
#
#
# start member: 023_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.626328945159912 to deal with 023_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.145532846450806 to deal with 023_max for year 2061
#
#
# start member: 024_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.928658962249756 to deal with 024_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 22.55213189125061 to deal with 024_max for year 2061
#
#
# start member: 025_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 27.516486167907715 to deal with 025_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.592576503753662 to deal with 025_max for year 2061
#
#
# start member: 026_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.76953840255737 to deal with 026_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.439282178878784 to deal with 026_max for year 2061
#
#
# start member: 027_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.95239019393921 to deal with 027_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.252516508102417 to deal with 027_max for year 2061
#
#
# start member: 028_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 33.14226675033569 to deal with 028_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.223278284072876 to deal with 028_max for year 2061
#
#
# start member: 029_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.71247100830078 to deal with 029_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 27.16776943206787 to deal with 029_max for year 2061
#
#
# start member: 030_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.95701026916504 to deal with 030_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.833537817001343 to deal with 030_max for year 2061
#
#
# start member: 031_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 28.954843044281006 to deal with 031_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.451531410217285 to deal with 031_max for year 2061
#
#
# start member: 032_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 32.676756381988525 to deal with 032_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 26.537238359451294 to deal with 032_max for year 2061
#
#
# start member: 033_max
# The quantile is: 0.98
# The duration threshold is: 2
# It took 29.539247035980225 to deal with 033_max for year 2006
# The quantile is: None
# The duration threshold is: 2
# It took 25.736656188964844 to deal with 033_max for year 2061

# %% [markdown]
# ## Merge to dataframe and save as csv

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)
quantile_avail_2061 = pd.concat(quantile_avail_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
quantile_avail_2061.to_csv(save_dir+"2061_percentile.csv")
