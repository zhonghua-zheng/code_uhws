# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the UHWs using **CMIP urban predictions**
#
# The data sets are from:
# ```bash
# /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/*/month/
# ```
#
# The results are saved at:
# ```
# S3://uhws/UHWs_CMIP/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import time
import gc
import util
from s3fs.core import S3FileSystem
s3 = S3FileSystem()

save_dir = "S3://uhws/UHWs_CMIP/"

# %%
CMIP5_ls = ["ACCESS1-0", "ACCESS1-3", "CanESM2", "CNRM-CM5", "CSIRO-Mk3-6-0",
            "FGOALS-s2","GFDL-CM3", "GFDL-ESM2G", "GFDL-ESM2M", "HadGEM2-CC",
            "HadGEM2-ES", "IPSL-CM5A-MR", "MIROC5", "MIROC-ESM", "MIROC-ESM-CHEM",
            "MRI-CGCM3", "MRI-ESM1"]

# %% [markdown]
# ## Step 1: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]

for model in CMIP5_ls:
    print("start model:",model)
    
    # start 2006
    start_time_2006=time.time()
    df_2006=util.load_df("/data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/"
                         "CMIP_2006/month/"+model+".csv")
    cmip_2006_hw, quantile_avail_2006=util.get_heat_waves_df(df_2006, 0.98, 2, "cmip", None)
    
    frequency_2006_ls.append(util.get_frequency(cmip_2006_hw,model))
    duration_2006_ls.append(util.get_duration(cmip_2006_hw,model))
    intensity_2006_ls.append(util.get_intensity(cmip_2006_hw,model))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": model}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",model,"for year 2006")

    
    # start 2061
    start_time_2061=time.time()
    df_2061=util.load_df("/data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/"
                         "CMIP_2061/month/"+model+".csv")
    cmip_2061_hw, quantile_avail_2061=util.get_heat_waves_df(df_2061, None, 2, "cmip", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cmip_2061_hw,model))
    duration_2061_ls.append(util.get_duration(cmip_2061_hw,model))
    intensity_2061_ls.append(util.get_intensity(cmip_2061_hw,model))
    
    print("It took",time.time()-start_time_2061,"to deal with",model,"for year 2061")
    print("\n")
    
    del df_2006, df_2061, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start model: ACCESS1-0
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/ACCESS1-0.csv
# It takes 20.469676733016968 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# /data/keeling/a/zzheng25/UrbanHWs/event_analysis/v4/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 46.65369009971619 to deal with ACCESS1-0 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/ACCESS1-0.csv
# It takes 21.707480907440186 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 44.94588613510132 to deal with ACCESS1-0 for year 2061
#
#
# start model: ACCESS1-3
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/ACCESS1-3.csv
# It takes 19.687917470932007 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 45.89206671714783 to deal with ACCESS1-3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/ACCESS1-3.csv
# It takes 22.829739332199097 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 45.84281063079834 to deal with ACCESS1-3 for year 2061
#
#
# start model: CanESM2
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/CanESM2.csv
# It takes 15.840182781219482 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 42.185370206832886 to deal with CanESM2 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/CanESM2.csv
# It takes 17.86202073097229 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 39.96016454696655 to deal with CanESM2 for year 2061
#
#
# start model: CNRM-CM5
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/CNRM-CM5.csv
# It takes 12.49524998664856 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.84613871574402 to deal with CNRM-CM5 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/CNRM-CM5.csv
# It takes 11.574039697647095 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.68496298789978 to deal with CNRM-CM5 for year 2061
#
#
# start model: CSIRO-Mk3-6-0
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/CSIRO-Mk3-6-0.csv
# It takes 11.68092393875122 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.08947944641113 to deal with CSIRO-Mk3-6-0 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/CSIRO-Mk3-6-0.csv
# It takes 20.975656270980835 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 46.41500782966614 to deal with CSIRO-Mk3-6-0 for year 2061
#
#
# start model: FGOALS-s2
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/FGOALS-s2.csv
# It takes 10.669901371002197 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.58961057662964 to deal with FGOALS-s2 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/FGOALS-s2.csv
# It takes 14.773248195648193 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 40.87193202972412 to deal with FGOALS-s2 for year 2061
#
#
# start model: GFDL-CM3
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/GFDL-CM3.csv
# It takes 12.21155333518982 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 39.48785090446472 to deal with GFDL-CM3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/GFDL-CM3.csv
# It takes 17.26412796974182 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 43.36210227012634 to deal with GFDL-CM3 for year 2061
#
#
# start model: GFDL-ESM2G
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/GFDL-ESM2G.csv
# It takes 14.681955814361572 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 46.02615785598755 to deal with GFDL-ESM2G for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/GFDL-ESM2G.csv
# It takes 13.762709617614746 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 38.73918318748474 to deal with GFDL-ESM2G for year 2061
#
#
# start model: GFDL-ESM2M
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/GFDL-ESM2M.csv
# It takes 10.350530624389648 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.80169129371643 to deal with GFDL-ESM2M for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/GFDL-ESM2M.csv
# It takes 9.070194482803345 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.989397764205933 to deal with GFDL-ESM2M for year 2061
#
#
# start model: HadGEM2-CC
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/HadGEM2-CC.csv
# It takes 9.151877164840698 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.94211483001709 to deal with HadGEM2-CC for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/HadGEM2-CC.csv
# It takes 11.375832796096802 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 33.84420967102051 to deal with HadGEM2-CC for year 2061
#
#
# start model: HadGEM2-ES
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/HadGEM2-ES.csv
# It takes 12.102953672409058 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 42.47297525405884 to deal with HadGEM2-ES for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/HadGEM2-ES.csv
# It takes 13.30213189125061 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 37.68466067314148 to deal with HadGEM2-ES for year 2061
#
#
# start model: IPSL-CM5A-MR
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/IPSL-CM5A-MR.csv
# It takes 9.538146018981934 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.76642179489136 to deal with IPSL-CM5A-MR for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/IPSL-CM5A-MR.csv
# It takes 10.87332034111023 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 33.86020565032959 to deal with IPSL-CM5A-MR for year 2061
#
#
# start model: MIROC5
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/MIROC5.csv
# It takes 11.017835855484009 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 41.43067646026611 to deal with MIROC5 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/MIROC5.csv
# It takes 9.252555131912231 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 33.92149257659912 to deal with MIROC5 for year 2061
#
#
# start model: MIROC-ESM
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/MIROC-ESM.csv
# It takes 10.023791551589966 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.638373136520386 to deal with MIROC-ESM for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/MIROC-ESM.csv
# It takes 10.027842998504639 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.905670881271362 to deal with MIROC-ESM for year 2061
#
#
# start model: MIROC-ESM-CHEM
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/MIROC-ESM-CHEM.csv
# It takes 9.011568307876587 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.348225116729736 to deal with MIROC-ESM-CHEM for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/MIROC-ESM-CHEM.csv
# It takes 11.407914638519287 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 40.238882303237915 to deal with MIROC-ESM-CHEM for year 2061
#
#
# start model: MRI-CGCM3
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/MRI-CGCM3.csv
# It takes 12.532297372817993 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.98237180709839 to deal with MRI-CGCM3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/MRI-CGCM3.csv
# It takes 10.131553411483765 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.05260491371155 to deal with MRI-CGCM3 for year 2061
#
#
# start model: MRI-ESM1
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2006/month/MRI-ESM1.csv
# It takes 9.148277521133423 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 39.46471118927002 to deal with MRI-ESM1 for year 2006
# Start to load csv /data/keeling/a/zzheng25/b/UrbanHWs/CMIP_predictions/CMIP_2061/month/MRI-ESM1.csv
# It takes 10.43920373916626 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 35.25554132461548 to deal with MRI-ESM1 for year 2061

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
