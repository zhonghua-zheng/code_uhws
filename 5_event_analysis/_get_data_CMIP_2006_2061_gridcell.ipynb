# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the UHWs using **CMIP grid cell** maximal tempeature
#
# The data sets are from:
# ```bash
# /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/
# ```
#
# The results are saved at:
# ```
# S3://uhws/RHWs_CMIP/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import gc
import util
from s3fs.core import S3FileSystem
s3 = S3FileSystem()

save_dir = "S3://uhws/RHWs_CMIP/"

# %%
CMIP5_ls = ["ACCESS1-0", "ACCESS1-3", "CanESM2", "CNRM-CM5", "CSIRO-Mk3-6-0",
            "FGOALS-s2","GFDL-CM3", "GFDL-ESM2G", "GFDL-ESM2M", "HadGEM2-CC",
            "HadGEM2-ES", "IPSL-CM5A-MR", "MIROC5", "MIROC-ESM", "MIROC-ESM-CHEM",
            "MRI-CGCM3", "MRI-ESM1"]

# %% [markdown]
# ## Step 1: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]

for model in CMIP5_ls:
    print("start model:",model)
    
    # start 2006
    start_time_2006=time.time()
    
    df_2006=util.load_df("/data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/"+model+"/2006.csv")
    cmip_2006_hw, quantile_avail_2006=util.get_heat_waves_df(df_2006, 0.98, 2, "cmip", None)
    
    frequency_2006_ls.append(util.get_frequency(cmip_2006_hw,model))
    duration_2006_ls.append(util.get_duration(cmip_2006_hw,model))
    intensity_2006_ls.append(util.get_intensity(cmip_2006_hw,model))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": model}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",model,"for year 2006")

    
    # start 2061
    start_time_2061=time.time()
    df_2061=util.load_df("/data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/"+model+"/2061.csv")
    cmip_2061_hw, quantile_avail_2061=util.get_heat_waves_df(df_2061, None, 2, "cmip", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cmip_2061_hw,model))
    duration_2061_ls.append(util.get_duration(cmip_2061_hw,model))
    intensity_2061_ls.append(util.get_intensity(cmip_2061_hw,model))
    
    print("It took",time.time()-start_time_2061,"to deal with",model,"for year 2061")
    print("\n")
    
    del df_2006, df_2061, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start model: ACCESS1-0
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/ACCESS1-0/2006.csv
# It takes 10.62881851196289 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# /data/keeling/a/zzheng25/UrbanHWs/event_analysis/v4/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 36.8468816280365 to deal with ACCESS1-0 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/ACCESS1-0/2061.csv
# It takes 11.019837141036987 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.916799545288086 to deal with ACCESS1-0 for year 2061
#
#
# start model: ACCESS1-3
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/ACCESS1-3/2006.csv
# It takes 10.401712417602539 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.41004157066345 to deal with ACCESS1-3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/ACCESS1-3/2061.csv
# It takes 10.443950176239014 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 33.87665820121765 to deal with ACCESS1-3 for year 2061
#
#
# start model: CanESM2
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CanESM2/2006.csv
# It takes 10.212414979934692 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.42604660987854 to deal with CanESM2 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CanESM2/2061.csv
# It takes 11.197375297546387 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 36.77770781517029 to deal with CanESM2 for year 2061
#
#
# start model: CNRM-CM5
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CNRM-CM5/2006.csv
# It takes 10.915764331817627 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 42.34996557235718 to deal with CNRM-CM5 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CNRM-CM5/2061.csv
# It takes 11.092084169387817 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 35.632970333099365 to deal with CNRM-CM5 for year 2061
#
#
# start model: CSIRO-Mk3-6-0
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CSIRO-Mk3-6-0/2006.csv
# It takes 11.42009687423706 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 41.776395082473755 to deal with CSIRO-Mk3-6-0 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/CSIRO-Mk3-6-0/2061.csv
# It takes 11.557186365127563 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 37.21281981468201 to deal with CSIRO-Mk3-6-0 for year 2061
#
#
# start model: FGOALS-s2
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/FGOALS-s2/2006.csv
# It takes 10.197361946105957 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.443784952163696 to deal with FGOALS-s2 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/FGOALS-s2/2061.csv
# It takes 11.675681352615356 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 36.324002504348755 to deal with FGOALS-s2 for year 2061
#
#
# start model: GFDL-CM3
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-CM3/2006.csv
# It takes 11.192208051681519 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 42.2280650138855 to deal with GFDL-CM3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-CM3/2061.csv
# It takes 10.46392035484314 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 35.384987115859985 to deal with GFDL-CM3 for year 2061
#
#
# start model: GFDL-ESM2G
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-ESM2G/2006.csv
# It takes 11.262559175491333 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.750351428985596 to deal with GFDL-ESM2G for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-ESM2G/2061.csv
# It takes 11.037789106369019 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.11613965034485 to deal with GFDL-ESM2G for year 2061
#
#
# start model: GFDL-ESM2M
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-ESM2M/2006.csv
# It takes 11.209718465805054 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.39780354499817 to deal with GFDL-ESM2M for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/GFDL-ESM2M/2061.csv
# It takes 11.07770848274231 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.83522033691406 to deal with GFDL-ESM2M for year 2061
#
#
# start model: HadGEM2-CC
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/HadGEM2-CC/2006.csv
# It takes 9.818225145339966 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 47.08068013191223 to deal with HadGEM2-CC for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/HadGEM2-CC/2061.csv
# It takes 10.681443929672241 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 43.874772787094116 to deal with HadGEM2-CC for year 2061
#
#
# start model: HadGEM2-ES
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/HadGEM2-ES/2006.csv
# It takes 10.985906600952148 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 48.3936402797699 to deal with HadGEM2-ES for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/HadGEM2-ES/2061.csv
# It takes 11.090811252593994 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 44.19937181472778 to deal with HadGEM2-ES for year 2061
#
#
# start model: IPSL-CM5A-MR
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/IPSL-CM5A-MR/2006.csv
# It takes 10.337580680847168 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.26148867607117 to deal with IPSL-CM5A-MR for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/IPSL-CM5A-MR/2061.csv
# It takes 10.516146421432495 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.93474316596985 to deal with IPSL-CM5A-MR for year 2061
#
#
# start model: MIROC5
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC5/2006.csv
# It takes 10.326821327209473 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.6448438167572 to deal with MIROC5 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC5/2061.csv
# It takes 10.73640489578247 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 33.03206276893616 to deal with MIROC5 for year 2061
#
#
# start model: MIROC-ESM
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC-ESM/2006.csv
# It takes 11.26123309135437 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 38.337894678115845 to deal with MIROC-ESM for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC-ESM/2061.csv
# It takes 10.5333993434906 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.05149483680725 to deal with MIROC-ESM for year 2061
#
#
# start model: MIROC-ESM-CHEM
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC-ESM-CHEM/2006.csv
# It takes 9.932867527008057 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 37.399643659591675 to deal with MIROC-ESM-CHEM for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MIROC-ESM-CHEM/2061.csv
# It takes 10.105898141860962 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 32.20802855491638 to deal with MIROC-ESM-CHEM for year 2061
#
#
# start model: MRI-CGCM3
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MRI-CGCM3/2006.csv
# It takes 10.41401743888855 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 40.34657955169678 to deal with MRI-CGCM3 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MRI-CGCM3/2061.csv
# It takes 11.19137454032898 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 35.89180946350098 to deal with MRI-CGCM3 for year 2061
#
#
# start model: MRI-ESM1
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MRI-ESM1/2006.csv
# It takes 10.68979525566101 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.53425884246826 to deal with MRI-ESM1 for year 2006
# Start to load csv /data/keeling/a/zzheng25/d/CMIP5_tasmax_csv/MRI-ESM1/2061.csv
# It takes 10.19882583618164 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 34.90193796157837 to deal with MRI-ESM1 for year 2061

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
