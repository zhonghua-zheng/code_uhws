# %% [markdown]
# This script is used to generate the frequency, total days, and intensity of the UHWs using **CMIP grid cell** maximal tempeature
#
# The data sets are from:
# ```bash
# /glade/scratch/zhonghua/CMIP5_tasmax_csv/
# ```
#
# The results are saved at:
# ```
# /glade/scratch/zhonghua/uhws/HWs_CMIP/
# ```
#
# Note:
# **2006**: Using 2006 itself to calculate the percentile, frequency, total days, and intensity
# **2061**: Using the percentile of **2006** to calculate frequency, total days, and intensity of 2061

# %%
import xarray as xr
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import gc
import util
# from s3fs.core import S3FileSystem
# s3 = S3FileSystem()

save_dir = "/glade/scratch/zhonghua/uhws/HWs_CMIP/"

# %%
CMIP5_ls = ["ACCESS1-0", "ACCESS1-3", "CanESM2", "CNRM-CM5", "CSIRO-Mk3-6-0",
            "FGOALS-s2","GFDL-CM3", "GFDL-ESM2G", "GFDL-ESM2M", "HadGEM2-CC",
            "HadGEM2-ES", "IPSL-CM5A-MR", "MIROC5", "MIROC-ESM", "MIROC-ESM-CHEM",
            "MRI-CGCM3", "MRI-ESM1"]

# %% [markdown]
# ## Step 1: Start the pipeline to use 98% percentile (2006) to get frequency (events/year), total days (days/year), and intensity (K) of 2006 and 2061

# %%
frequency_2006_ls=[]
duration_2006_ls=[]
intensity_2006_ls=[]
quantile_avail_2006_ls=[]

frequency_2061_ls=[]
duration_2061_ls=[]
intensity_2061_ls=[]

for model in CMIP5_ls:
    print("start model:",model)
    
    # start 2006
    start_time_2006=time.time()
    
    df_2006=util.load_df("/glade/scratch/zhonghua/CMIP5_tasmax_csv/"+model+"/2006.csv")
    cmip_2006_hw, quantile_avail_2006=util.get_heat_waves_df(df_2006, 0.98, 2, "cmip", None)
    
    frequency_2006_ls.append(util.get_frequency(cmip_2006_hw,model))
    duration_2006_ls.append(util.get_duration(cmip_2006_hw,model))
    intensity_2006_ls.append(util.get_intensity(cmip_2006_hw,model))
    quantile_avail_2006_ls.append(quantile_avail_2006.copy().rename(columns={"quant": model}).set_index(["lat","lon"]))
    print("It took",time.time()-start_time_2006,"to deal with",model,"for year 2006")

    
    # start 2061
    start_time_2061=time.time()
    df_2061=util.load_df("/glade/scratch/zhonghua/CMIP5_tasmax_csv/"+model+"/2061.csv")
    cmip_2061_hw, quantile_avail_2061=util.get_heat_waves_df(df_2061, None, 2, "cmip", quantile_avail_2006)
    
    frequency_2061_ls.append(util.get_frequency(cmip_2061_hw,model))
    duration_2061_ls.append(util.get_duration(cmip_2061_hw,model))
    intensity_2061_ls.append(util.get_intensity(cmip_2061_hw,model))
    
    print("It took",time.time()-start_time_2061,"to deal with",model,"for year 2061")
    print("\n")
    
    del df_2006, df_2061, quantile_avail_2006, quantile_avail_2061
    gc.collect()
# Out:
# start model: ACCESS1-0
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/ACCESS1-0/2006.csv
# It takes 9.008928537368774 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# /glade/work/zhonghua/code_uhws_ncc_private/3_revision/5_event_analysis/util.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_quantile["HW"][df_with_quantile["mean"]> df_with_quantile["quant"]] = 0
# It took 37.13364505767822 to deal with ACCESS1-0 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/ACCESS1-0/2061.csv
# It takes 8.5313560962677 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.91027569770813 to deal with ACCESS1-0 for year 2061
#
#
# start model: ACCESS1-3
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/ACCESS1-3/2006.csv
# It takes 8.381752490997314 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.10240578651428 to deal with ACCESS1-3 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/ACCESS1-3/2061.csv
# It takes 8.415366888046265 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.011895179748535 to deal with ACCESS1-3 for year 2061
#
#
# start model: CanESM2
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CanESM2/2006.csv
# It takes 8.370239973068237 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.82221174240112 to deal with CanESM2 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CanESM2/2061.csv
# It takes 8.459201335906982 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.049004316329956 to deal with CanESM2 for year 2061
#
#
# start model: CNRM-CM5
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CNRM-CM5/2006.csv
# It takes 8.287915468215942 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.014423847198486 to deal with CNRM-CM5 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CNRM-CM5/2061.csv
# It takes 8.52025055885315 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.37103009223938 to deal with CNRM-CM5 for year 2061
#
#
# start model: CSIRO-Mk3-6-0
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CSIRO-Mk3-6-0/2006.csv
# It takes 8.28474497795105 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.866408348083496 to deal with CSIRO-Mk3-6-0 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/CSIRO-Mk3-6-0/2061.csv
# It takes 8.375792741775513 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.146978616714478 to deal with CSIRO-Mk3-6-0 for year 2061
#
#
# start model: FGOALS-s2
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/FGOALS-s2/2006.csv
# It takes 8.38154125213623 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.079216957092285 to deal with FGOALS-s2 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/FGOALS-s2/2061.csv
# It takes 8.422366619110107 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.040879487991333 to deal with FGOALS-s2 for year 2061
#
#
# start model: GFDL-CM3
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-CM3/2006.csv
# It takes 8.319081544876099 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.00880002975464 to deal with GFDL-CM3 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-CM3/2061.csv
# It takes 8.372105598449707 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.277920484542847 to deal with GFDL-CM3 for year 2061
#
#
# start model: GFDL-ESM2G
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-ESM2G/2006.csv
# It takes 8.396450281143188 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.2360680103302 to deal with GFDL-ESM2G for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-ESM2G/2061.csv
# It takes 8.413218259811401 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.678670167922974 to deal with GFDL-ESM2G for year 2061
#
#
# start model: GFDL-ESM2M
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-ESM2M/2006.csv
# It takes 8.405150413513184 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.43429255485535 to deal with GFDL-ESM2M for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/GFDL-ESM2M/2061.csv
# It takes 14.873624563217163 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 36.881550788879395 to deal with GFDL-ESM2M for year 2061
#
#
# start model: HadGEM2-CC
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/HadGEM2-CC/2006.csv
# It takes 8.34285831451416 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 44.36229372024536 to deal with HadGEM2-CC for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/HadGEM2-CC/2061.csv
# It takes 8.192195177078247 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 40.63162016868591 to deal with HadGEM2-CC for year 2061
#
#
# start model: HadGEM2-ES
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/HadGEM2-ES/2006.csv
# It takes 8.206265211105347 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 44.75158905982971 to deal with HadGEM2-ES for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/HadGEM2-ES/2061.csv
# It takes 8.246965885162354 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 39.48185968399048 to deal with HadGEM2-ES for year 2061
#
#
# start model: IPSL-CM5A-MR
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/IPSL-CM5A-MR/2006.csv
# It takes 8.348614931106567 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.006096839904785 to deal with IPSL-CM5A-MR for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/IPSL-CM5A-MR/2061.csv
# It takes 8.36200499534607 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 31.575482845306396 to deal with IPSL-CM5A-MR for year 2061
#
#
# start model: MIROC5
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC5/2006.csv
# It takes 8.302151918411255 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.572774171829224 to deal with MIROC5 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC5/2061.csv
# It takes 8.250997543334961 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.066767692565918 to deal with MIROC5 for year 2061
#
#
# start model: MIROC-ESM
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC-ESM/2006.csv
# It takes 8.235999822616577 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 34.86109447479248 to deal with MIROC-ESM for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC-ESM/2061.csv
# It takes 8.274019002914429 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.17592716217041 to deal with MIROC-ESM for year 2061
#
#
# start model: MIROC-ESM-CHEM
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC-ESM-CHEM/2006.csv
# It takes 8.215619325637817 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.10138940811157 to deal with MIROC-ESM-CHEM for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MIROC-ESM-CHEM/2061.csv
# It takes 8.266937255859375 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.30434823036194 to deal with MIROC-ESM-CHEM for year 2061
#
#
# start model: MRI-CGCM3
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MRI-CGCM3/2006.csv
# It takes 8.259034156799316 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 35.27718687057495 to deal with MRI-CGCM3 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MRI-CGCM3/2061.csv
# It takes 8.369896173477173 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.31929874420166 to deal with MRI-CGCM3 for year 2061
#
#
# start model: MRI-ESM1
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MRI-ESM1/2006.csv
# It takes 8.492225408554077 to load csv
# The quantile is: 0.98
# The duration threshold is: 2
# It took 36.09552574157715 to deal with MRI-ESM1 for year 2006
# Start to load csv /glade/scratch/zhonghua/CMIP5_tasmax_csv/MRI-ESM1/2061.csv
# It takes 8.434707403182983 to load csv
# The quantile is: None
# The duration threshold is: 2
# It took 30.34616994857788 to deal with MRI-ESM1 for year 2061

# %%
frequency_2006 = pd.concat(frequency_2006_ls, axis=1)
duration_2006 = pd.concat(duration_2006_ls, axis=1)
intensity_2006 = pd.concat(intensity_2006_ls, axis=1)
quantile_avail_2006 = pd.concat(quantile_avail_2006_ls, axis=1)

frequency_2061 = pd.concat(frequency_2061_ls, axis=1)
duration_2061 = pd.concat(duration_2061_ls, axis=1)
intensity_2061 = pd.concat(intensity_2061_ls, axis=1)

# %%
# here the quantile 2006 and quantile 2061 should be same
frequency_2006.to_csv(save_dir+"2006_frequency.csv")
duration_2006.to_csv(save_dir+"2006_totaldays.csv")
intensity_2006.to_csv(save_dir+"2006_intensity.csv")
quantile_avail_2006.to_csv(save_dir+"2006_percentile.csv")

frequency_2061.to_csv(save_dir+"2061_frequency.csv")
duration_2061.to_csv(save_dir+"2061_totaldays.csv")
intensity_2061.to_csv(save_dir+"2061_intensity.csv")
